# %%
import pandas as pd
import numpy as np
import math
from funcoes_captura_cvm import *

ano_mes = "202110"
lista_fundos = [
("36.178.569/0001-99","cotas fundos bolsa america.xlsx","BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO EM ACOES",'45699'),
("08.973.951/0001-59","cotas fundos siderurgia.xlsx","BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM COTAS DE FUNDOS DE INVESTIMENTO",'19704'),
("31.963.249/0001-26","cotas do fundo de renda fixa.xlsx","BB RENDA FIXA LONGO PRAZO CREDITO PRIVADO FUNDO DE INVESTIMENTO EM COTAS DE FI",'40977')
]

print("Capturando dados da cvm para " + ano_mes)
df_fundos_cvm = cria_df_novo(ano_mes,lista_fundos)

## Criar uma função que captura os dados da base e deixa comentado
## a função que puxa os dados do historico

print('Juntando dados da cvm com dados historicos(local)')
df_fundos_total = junta_df(df_fundos_cvm, lista_fundos)
df_fundos_total

print('Ajustando variações')
df_fundos_total = ajuste_variacao(df_fundos_total)

print('Exportando dataframe para arquivo csv')
df_fundos_total.to_csv('Base_Historica_Fundos_CVM.csv', index=False)

print('Fim da captura dos dados de fundos na CVM')
# Out:
# Capturando dados da cvm para 202110
# Captura dados da CVM
# Filtrando dados capturados
# Selecionando na base dados do fundo BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO EM ACOES
# Selecionando na base dados do fundo BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM COTAS DE FUNDOS DE INVESTIMENTO
# Selecionando na base dados do fundo BB RENDA FIXA LONGO PRAZO CREDITO PRIVADO FUNDO DE INVESTIMENTO EM COTAS DE FI
# Ajustando dataframe
# Concatenando os dataframe de cada fundo em um fundo
# Ordenando dataframa
# Juntando dados da cvm com dados historicos(local)
# Capturando dados do historico dos fundos
# Tratando dados da cvm para concatenação
# Concatenando dados historicos com dados da cvm
# Ajustando variações
# Exportando dataframe para arquivo csv
# Fim da captura dos dados de fundos na CVM

# %%
df_fundos_total
# Out:
#               CNPJ_FUNDO                                         NOME_FUNDO  \
# 0     08.973.951/0001-59  BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM C...
# 1     08.973.951/0001-59  BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM C...
# 2     08.973.951/0001-59  BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM C...
# 3     08.973.951/0001-59  BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM C...
# 4     08.973.951/0001-59  BB ACOES SIDERURGIA FUNDO DE INVESTIMENTO EM C...
# ...                  ...                                                ...
# 4608  36.178.569/0001-99  BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO...
# 4609  36.178.569/0001-99  BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO...
# 4610  36.178.569/0001-99  BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO...
# 4611  36.178.569/0001-99  BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO...
# 4612  36.178.569/0001-99  BB ACOES BOLSA AMERICANA FUNDO DE INVESTIMENTO...
#
#             DATA      COTA  VARIACAO     CAPTACAO     RESGATE            PL  \
# 0     2007-10-03  1.000000       NaN   1558725.73        0.00  1.558726e+06
# 1     2007-10-04  0.994895 -0.005105   1929219.52        0.00  3.479989e+06
# 2     2007-10-05  1.021774  0.027017    998941.39        0.00  4.572948e+06
# 3     2007-10-08  1.029555  0.007615   1104929.29     1965.13  5.710737e+06
# 4     2007-10-09  1.045901  0.015877   1813113.95    14507.54  7.600014e+06
# ...          ...       ...       ...          ...         ...           ...
# 4608  2021-10-11  1.509533 -0.006463   6017883.09  2089749.24  2.116614e+09
# 4609  2021-10-13  1.512937  0.002255   3745053.31  1805413.59  2.123327e+09
# 4610  2021-10-14  1.539807  0.017760   4069677.01  3155742.11  2.161952e+09
# 4611  2021-10-15  1.551140  0.007360   3736420.06  1878734.73  2.179722e+09
# 4612  2021-10-18  1.554178  0.001958  42370918.82  1792871.77  2.224568e+09
#
#       COTISTA
# 0       269.0
# 1       592.0
# 2       883.0
# 3      1150.0
# 4      1515.0
# ...       ...
# 4608  45263.0
# 4609  45247.0
# 4610  45228.0
# 4611  45219.0
# 4612  45254.0
#
# [4613 rows x 9 columns]
